# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# %%
# URL of page to be scraped
url = "http://www.espn.com/nhl/team/schedule/_/name/nyi/new-york-islanders"

# %%
# Retrieve page with the requests module
response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml">
#  <head>
#   <script src="http://cdn.espn.com/sports/optimizely.js">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <link href="http://a.espncdn.com/favicon.ico" mask="" rel="icon" sizes="any"/>
#   <meta content="#CC0000" name="theme-color"/>
#   <script type="text/javascript">
#    if(true && navigator && navigator.userAgent.toLowerCase().indexOf("teamstream") >= 0) {
#         window.location = 'http://m.espn.com/mobilecache/general/apps/sc';
#     }
#   </script>
#   <script>
# ...

# %%
# results are returned as an iterable list
results = soup.find_all('li', class_="team-name")

# %%
print(results)
# Out:
# [<li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers">Philadelphia</a></li>, <li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers">Philadelphia</a></li>, <li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers">Philadelphia</a></li>, <li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/nj/new-jersey-devils">New Jersey</a></li>, <li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers">Philadelphia</a></li>, <li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/nyr/new-york-rangers">NY Rangers</a></li>, <li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/nyr/new-york-rangers">NY Rangers</a></li>, <li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/buf/buffalo-sabres">Buffalo</a></li>, <li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/car/carolina-hurricanes">Carolina</
# ...

# %%
for div in soup.findAll('li', attrs={'class':'team-name'}):
    #print (div.find('a')['href'])
    print (div.find('a').contents[0])
# Out:
# Philadelphia
# Philadelphia
# Philadelphia
# New Jersey
# Philadelphia
# NY Rangers
# NY Rangers
# Buffalo
# Carolina
# Nashville
# San Jose
# Nashville
# Anaheim
# Los Angeles
# San Jose
# Florida
# Philadelphia
# Carolina
# Pittsburgh
# Pittsburgh
# New Jersey
# Montreal
# Tampa Bay
# Florida
# Vancouver
# NY Rangers
# Dallas
# NY Rangers
# New Jersey
# Carolina
# Washington
# Boston
# Columbus
# Winnipeg
# Pittsburgh
# Detroit
# Pittsburgh
# Vegas
# Detroit
# Colorado
# Arizona
# Vegas
# Dallas
# Ottawa
# Toronto
# Buffalo
# Chicago
# St. Louis
# Carolina
# NY Rangers
# NY Rangers
# Tampa Bay
# St. Louis
# New Jersey
# Washington
# Anaheim
# Chicago
# Tampa Bay
# Los Angeles
# Boston
# New Jersey
# Colorado
# Minnesota
# Buffalo
# Columbus
# Edmonton
# Calgary
# Edmonton
# Vancouver
# Calgary
# Toronto
# Washington
# Philadelphia
# Ottawa
# Ottawa
# Philadelphia
# Columbus
# Montreal
# Detroit
# Minnesota
# Boston
# Montreal
# Philadelphia
# Arizona
# Columbus
# Winnipeg
# ...

# %%
for div in soup.findAll('li', attrs={'class':'team-logo-small logo-nhl-small'}):
    #print (div.find('a')['href'])
    #print (div.find('a').contents[0])
    print (div.find('img')['src'])
# Out:
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Phi.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Phi.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Phi.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/NJ.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Phi.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/NYR.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/NYR.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Buf.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Car.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Nsh.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/SJ.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Nsh.png&h=80&w=80
# http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/ANA.png&h=80&w=80
# ...

# %%
# results are returned as an iterable list
results = soup.find_all('tr', class_="oddrow team-90-15")
print(results)
# Out:
# [<tr class="oddrow team-90-15"><td>Sun, Sep 16</td><td><ul class="game-schedule"><li class="game-status">vs</li><li class="team-logo-small logo-nhl-small"><a href="http://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers"><img src="http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Phi.png&amp;h=80&amp;w=80"/></a></li><li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers">Philadelphia</a></li></ul></td><td>1:00 PM</td><td align="center"> </td>
# <td></td>
# ...

# %%
# results are returned as an iterable list
results = soup.find_all('tr')
print(results)
# Out:
# [<tr class="stathead"><td colspan="9">2019 Preseason Schedule</td></tr>, <tr class="colhead"><td>SEPTEMBER</td><td>OPPONENT</td><td>TIME (ET)</td><td>TV</td><td>LOCAL TV</td><td>TICKETS</td><td colspan="3">LOCATION</td></tr>, <tr class="oddrow team-90-15"><td>Sun, Sep 16</td><td><ul class="game-schedule"><li class="game-status">vs</li><li class="team-logo-small logo-nhl-small"><a href="http://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers"><img src="http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Phi.png&amp;h=80&amp;w=80"/></a></li><li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers">Philadelphia</a></li></ul></td><td>1:00 PM</td><td align="center"> </td>
# <td></td>
# ...

# %%
result = soup.find_all('td')
print(result)
# Out:
# [<td colspan="9">2019 Preseason Schedule</td>, <td>SEPTEMBER</td>, <td>OPPONENT</td>, <td>TIME (ET)</td>, <td>TV</td>, <td>LOCAL TV</td>, <td>TICKETS</td>, <td colspan="3">LOCATION</td>, <td>Sun, Sep 16</td>, <td><ul class="game-schedule"><li class="game-status">vs</li><li class="team-logo-small logo-nhl-small"><a href="http://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers"><img src="http://a.espncdn.com/combiner/i?img=/i/teamlogos/nhl/500/Phi.png&amp;h=80&amp;w=80"/></a></li><li class="team-name"><a href="http://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers">Philadelphia</a></li></ul></td>, <td>1:00 PM</td>, <td align="center"> </td>, <td></td>, <td><a href="https://www.vividseats.com/nhl-hockey/new-york-islanders-tickets/islanders-9-16-2749532.html?wsUser=717" name="&amp;lpos=nhl:team:schedule:tickets">1,444 available from $14</a></td>, <td colspan="3">Nassau Veterans Memorial Coliseum</td>, <td>Mon, Sep 17</td>, <td><ul class="game-schedule"><li class="game-status">@<
# ...

# %%
for div in soup.findAll('tr'):
    #print (div.find('a')['href'])
    print (div.find('td').contents[0])
# Out:
# 2019 Preseason Schedule
# SEPTEMBER
# Sun, Sep 16
# Mon, Sep 17
# Tue, Sep 18
# Thu, Sep 20
# Fri, Sep 21
# Sat, Sep 22
# Wed, Sep 26
# Fri, Sep 28
# 2019 Regular Season Schedule
# OCTOBER
# Thu, Oct 4
# Sat, Oct 6
# Mon, Oct 8
# Sat, Oct 13
# Wed, Oct 17
# Thu, Oct 18
# Sat, Oct 20
# Wed, Oct 24
# Sat, Oct 27
# Sun, Oct 28
# Tue, Oct 30
# NOVEMBER
# Thu, Nov 1
# Sat, Nov 3
# Mon, Nov 5
# Thu, Nov 8
# Sat, Nov 10
# Tue, Nov 13
# Thu, Nov 15
# Sun, Nov 18
# Wed, Nov 21
# Fri, Nov 23
# Sat, Nov 24
# Mon, Nov 26
# Thu, Nov 29
# DECEMBER
# Sat, Dec 1
# Tue, Dec 4
# Thu, Dec 6
# Sat, Dec 8
# Mon, Dec 10
# Wed, Dec 12
# Sat, Dec 15
# Mon, Dec 17
# Tue, Dec 18
# Thu, Dec 20
# Sun, Dec 23
# Fri, Dec 28
# Sat, Dec 29
# Mon, Dec 31
# JANUARY
# Thu, Jan 3
# Sat, Jan 5
# Tue, Jan 8
# Thu, Jan 10
# Sat, Jan 12
# Sun, Jan 13
# Tue, Jan 15
# Thu, Jan 17
# Fri, Jan 18
# Sun, Jan 20
# Tue, Jan 22
# FEBRUARY
# Fri, Feb 1
# Sat, Feb 2
# Tue, Feb 5
# Thu, Feb 7
# Sat, Feb 9
# Sun, Feb 10
# Tue, Feb 12
# ...

# %%
for div in soup.findAll('tr'):
    #print (div.find('a')['href'])
    print (div.find('td').contents[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-1a71f72042aa> in <module>()
#       1 for div in soup.findAll('tr'):
#       2     #print (div.find('a')['href'])
# ----> 3     print (div.find('td').contents[4])
#
# IndexError: list index out of range

# %%
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('a', class_="team-name").text
        # Identify and return price of listing
        name = result.a.span.text
        # Identify and return link to listing
        link = result.a['href']

        # Print results only if title, price, and link are available
        if (team-name):
            print('-------------')
            print(team-name)
            #print(price)
            #print(link)
    except AttributeError as e:
        print(e)
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# ...
